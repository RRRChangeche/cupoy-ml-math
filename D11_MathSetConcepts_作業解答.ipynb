# %% [markdown]
# (1) 用列舉法寫出下面的集合：
# (a)A={x|x^2−9x+20=0} (b)B={m/n|m,n∈N 且 m+n=5}
#
# ans: A={5,4}, B={4/1,3/2,2/3,1/4}
#
# (2) 設 A={1，{1}，{2}，{1,2}}，則下列那些是正確的？
# (A){1}∈A (B){1}⊂A (C)2∈A (D){1,2}⊂A (E){1,2}∈A。
#
# ans: A, B, E
#
# (3) 設 S={φ，1，{1,2}，3}，則下列那些是正確的
# (A) φ∈S (B)φ⊂S (C)2∈S (D){1,2}∈S (E){1,2,3}⊂S。
#
# ans:A, B, D
#
# (4) 設 A={x,y,z}，B={x+1,2,3}，若 A=B，則有序數對(x,y,z)共有幾組？
#
# ans: 5
#
# (5) 設 A 集合有 7 個元素，B 集合有 5 個元素，則(1) A∩ B 至多有幾個元素？(2)
# A∩ B 至少有幾個元素？
#
# ans: 5, 0
