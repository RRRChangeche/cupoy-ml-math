# %% [markdown]
# 假設有兩種顏色的球，共有三顆，每顆球有直徑跟厚度兩個特徵，如下
#
#
# 直徑  厚度  類別
#
#   5         1      紅
#
#   4         2      紅
#
#   1         5      藍
#
#
#
# 可以發現紅色的直徑較大但厚度較薄，藍色的直徑較小厚度較厚，這裡要讓大家清楚的是在機器學習中的每個特徵都是一維。以第一筆數據舉例，直徑5厚度1用座標表示為(5, 1)。
#
#
# 作業要求如下，共兩個需要完成:
#
# Step1、請大家試著畫出上述三筆數據在座標中的樣子，並用不同顏色標示紅跟籃球。
#
# Step2、如前面章節所述(連結如下)，當你了解每一筆數據實際上在座標上的樣貌時，就能夠用回歸模型來做預測。這裡要做的就是畫一條線去將紅、藍兩類分隔開來。

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

plt.scatter([5, 4, 1],[1, 2, 5], c=["red", "red", "blue"])
plt.plot([1,2,3,4,5])
plt.xlabel("Diameter")
plt.ylabel("Thickness")
plt.show()
