# %% [markdown]
# 向量加減法作業
#
# u = (–1;5), v = (2.7;3.8), w = (4.2;–6).求以下向量

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 向量內積作業：求以下向量之內積

# %% [markdown]
# ![image.png](data:image/png;base64,...)
