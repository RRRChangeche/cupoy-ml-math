# %% [markdown]
# 教室裡有24人，8人熱愛運動，14人是男生，男生且熱愛運動有5人，假設某A喜歡運動，此人為男生的機率是多少？

# %% [markdown]
# P(男生|喜歡運動) = P(男生)*P(喜歡運動|男生)/P(喜歡運動)
#
# 其中
#
# P(喜歡運動) = 8/24
#
# P(男生) = 14/24
#
# P(喜歡運動|男生) = 5/14
#
# 所以
#
# P(男生|喜歡運動) = 14/24 * 5/14 / (8/24) = 5/8
