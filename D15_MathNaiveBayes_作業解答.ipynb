# %% [markdown]
# 教室裡有24人，8人熱愛運動，14人是男生，男生且熱愛運動有5人，假設某A喜歡運動，此人為男生的機率是多少？

# %% [markdown]
# 解答：：
#
# P(熱愛運動|男) = "P(男∩熱愛運動)" /"P(男)"  = "5/24" /"14/24"  = 5/14
#
# P(男|熱愛運動) = "P(熱愛運動|男) P(男)" /"P(熱愛運動)" = "5/14 ∗ 14/24" /"8/24"  = (5/24)/(8/24) = 5/8
